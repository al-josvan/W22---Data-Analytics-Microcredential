# %% [markdown]
# <a href="https://colab.research.google.com/github/al-josvan/W22---Data-Analytics-Microcredential/blob/main/Python/Property_and_Election_Dataset_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Part 1

# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_csv('https://raw.githubusercontent.com/CunyLaguardiaDataAnalytics/datasets/master/property.csv')

# %%
data
# Out:
#            PID  ST_NUM     ST_NAME OWN_OCCUPIED NUM_BEDROOMS NUM_BATH SQ_FT
# 0  100001000.0   104.0      PUTNAM            Y            3        1  1000
# 1  100002000.0   197.0   LEXINGTON            N            3      1.5    --
# 2  100003000.0     NaN   LEXINGTON            N          NaN        1   850
# 3  100004000.0   201.0    BERKELEY           12            1      NaN   700
# 4          NaN   203.0    BERKELEY            Y            3        2  1600
# 5  100006000.0   207.0    BERKELEY            Y          NaN        1   800
# 6  100007000.0     NaN  WASHINGTON          NaN            2   HURLEY   950
# 7  100008000.0   213.0     TREMONT            Y            1        1   NaN
# 8  100009000.0   215.0     TREMONT            Y           na        2  1800

# %%
data.info()   #displays information about data set
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9 entries, 0 to 8
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   PID           8 non-null      float64
#  1   ST_NUM        7 non-null      float64
#  2   ST_NAME       9 non-null      object
#  3   OWN_OCCUPIED  8 non-null      object
#  4   NUM_BEDROOMS  7 non-null      object
#  5   NUM_BATH      8 non-null      object
#  6   SQ_FT         8 non-null      object
# dtypes: float64(2), object(5)
# memory usage: 632.0+ bytes

# %%
# Declaring a new variable
# assigning data into the new variable which contains
# the same data from the old 'PID' Column but values with the NaN values
# replaced with another value, '10000500.0'

new_PID = data['PID'].fillna(100005000.0)

# %%
# The drop function is being called to drop/delete the column labeled 'PID'
# by assigning 'inplace = True', the change becomes permanent 

data.drop(labels = 'PID', axis = 1, inplace = True)

# %%
# Creating a new column called 'PID'
# Assigning the data held within the variable 'new_PID' into the new column

data['PID'] = new_PID

# %%
# adding PID as the index

data.set_index('PID', inplace = True)

# %%
# Copying the data frame stored within the variable 'data'
# Creating a new variable called 'data2'
# Assigning/storing the data frame within 'data' into new var, 'data2'

data2 = data

# %%
data2
# Out:
#              ST_NUM     ST_NAME OWN_OCCUPIED NUM_BEDROOMS NUM_BATH SQ_FT
# PID
# 100001000.0   104.0      PUTNAM            Y            3        1  1000
# 100002000.0   197.0   LEXINGTON            N            3      1.5    --
# 100003000.0     NaN   LEXINGTON            N          NaN        1   850
# 100004000.0   201.0    BERKELEY           12            1      NaN   700
# 100005000.0   203.0    BERKELEY            Y            3        2  1600
# 100006000.0   207.0    BERKELEY            Y          NaN        1   800
# 100007000.0     NaN  WASHINGTON          NaN            2   HURLEY   950
# 100008000.0   213.0     TREMONT            Y            1        1   NaN
# 100009000.0   215.0     TREMONT            Y           na        2  1800

# %%
# Creating a new variable called 'df_no_wash'
# Assigning the data frame stored in the variable data2
# Calling the drop function on data2
# removed the row that started with index [100007000.0]

df_no_wash = data2.drop([100007000.0], axis = 0)

# %%
df_no_wash
# Out:
#              ST_NUM    ST_NAME OWN_OCCUPIED NUM_BEDROOMS NUM_BATH SQ_FT
# PID
# 100001000.0   104.0     PUTNAM            Y            3        1  1000
# 100002000.0   197.0  LEXINGTON            N            3      1.5    --
# 100003000.0     NaN  LEXINGTON            N          NaN        1   850
# 100004000.0   201.0   BERKELEY           12            1      NaN   700
# 100005000.0   203.0   BERKELEY            Y            3        2  1600
# 100006000.0   207.0   BERKELEY            Y          NaN        1   800
# 100008000.0   213.0    TREMONT            Y            1        1   NaN
# 100009000.0   215.0    TREMONT            Y           na        2  1800

# %%
df_no_wash
# Out:
#              ST_NUM    ST_NAME OWN_OCCUPIED NUM_BEDROOMS NUM_BATH SQ_FT
# PID
# 100001000.0   104.0     PUTNAM            Y            3        1  1000
# 100002000.0   197.0  LEXINGTON            N            3      1.5    --
# 100003000.0     NaN  LEXINGTON            N          NaN        1   850
# 100004000.0   201.0   BERKELEY           12            1      NaN   700
# 100005000.0   203.0   BERKELEY            Y            3        2  1600
# 100006000.0   207.0   BERKELEY            Y          NaN        1   800
# 100008000.0   213.0    TREMONT            Y            1        1   NaN
# 100009000.0   215.0    TREMONT            Y           na        2  1800

# %%
# Calling the variable, df_no_wash
# displaying the data stored in the column, 'SQ_FT'
# calling the string function which converts to string
# calling the boolean function, isnumeric(), which returns true/false
# if the values are numeric values or not numeric values

df_no_wash['SQ_FT'].str.isnumeric()
# Out:
# PID
# 100001000.0     True
# 100002000.0    False
# 100003000.0     True
# 100004000.0     True
# 100005000.0     True
# 100006000.0     True
# 100008000.0      NaN
# 100009000.0     True
# Name: SQ_FT, dtype: object

# %%
# creating new variable called, df_no_wash_na
# calling 'fillna()' function on the variable df_no_wash which fills 
# all the NaN values with the values 0
# Assigning such mutation to df_no_wash into the new variable df_no_wash_na

df_no_wash_na = df_no_wash.fillna(value= 0)
df_no_wash_na
# Out:
#              ST_NUM    ST_NAME OWN_OCCUPIED NUM_BEDROOMS NUM_BATH SQ_FT
# PID
# 100001000.0   104.0     PUTNAM            Y            3        1  1000
# 100002000.0   197.0  LEXINGTON            N            3      1.5    --
# 100003000.0     0.0  LEXINGTON            N            0        1   850
# 100004000.0   201.0   BERKELEY           12            1        0   700
# 100005000.0   203.0   BERKELEY            Y            3        2  1600
# 100006000.0   207.0   BERKELEY            Y            0        1   800
# 100008000.0   213.0    TREMONT            Y            1        1     0
# 100009000.0   215.0    TREMONT            Y           na        2  1800

# %%
# accessing the data from df_no_wash_na at the column, 'SQ FT'
# accessing the data from df_no_wash_na at the specific index, [100002000.0]
# changing the value stored at the specific index to 0

df_no_wash_na['SQ_FT'][100002000.0] = 0
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """

# %%
df_no_wash_na
# Out:
#              ST_NUM    ST_NAME OWN_OCCUPIED NUM_BEDROOMS NUM_BATH SQ_FT
# PID
# 100001000.0   104.0     PUTNAM            Y            3        1  1000
# 100002000.0   197.0  LEXINGTON            N            3      1.5     0
# 100003000.0     0.0  LEXINGTON            N            0        1   850
# 100004000.0   201.0   BERKELEY           12            1        0   700
# 100005000.0   203.0   BERKELEY            Y            3        2  1600
# 100006000.0   207.0   BERKELEY            Y            0        1   800
# 100008000.0   213.0    TREMONT            Y            1        1     0
# 100009000.0   215.0    TREMONT            Y           na        2  1800

# %%
# creating the variable, sqft_sum
# calling df_no_wash_na and displaying only two columns
# assigning the shortened data frame into our new variable

sqft_sum = df_no_wash_na[['ST_NAME', 'SQ_FT']]

# %%
sqft_sum
# Out:
#                ST_NAME SQ_FT
# PID
# 100001000.0     PUTNAM  1000
# 100002000.0  LEXINGTON     0
# 100003000.0  LEXINGTON   850
# 100004000.0   BERKELEY   700
# 100005000.0   BERKELEY  1600
# 100006000.0   BERKELEY   800
# 100008000.0    TREMONT     0
# 100009000.0    TREMONT  1800

# %%
# calling the astype() on the sqft_sum variable 
# changing/casting the type of 'SQ_FT' from object type to interger type

sqft_sum.astype({'SQ_FT': 'int32'}).dtypes
# Out:
# ST_NAME    object
# SQ_FT       int32
# dtype: object

# %% [markdown]
# # Part 2

# %% [markdown]
# # which state had the most votes
# # which state had the most turn out

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as go

# %%
df_election = pd.read_csv('https://raw.githubusercontent.com/glopez21/ML-Data/main/2020%20November%20General%20Election%20-%20Turnout%20Rates.csv')

# %%
# preview of the data
df_election.head()
# Out:
#            State  ... State Abv
# 0  United States  ...       NaN
# 1        Alabama  ...        AL
# 2         Alaska  ...        AK
# 3        Arizona  ...        AZ
# 4       Arkansas  ...        AR
#
# [5 rows x 15 columns]

# %%
# checking what columns the dataset is using
df_election.columns
# Out:
# Index(['State', 'Source', 'Official/Unofficial',
#        'Total Ballots Counted (Estimate)',
#        'Vote for Highest Office (President)', 'VEP Turnout Rate',
#        'Voting-Eligible Population (VEP)', 'Voting-Age Population (VAP)',
#        '% Non-citizen', 'Prison', 'Probation', 'Parole',
#        'Total Ineligible Felon', 'Overseas Eligible', 'State Abv'],
#       dtype='object')

# %%
# Looking at the entire dataset once over
df_election
# Out:
#                    State  ... State Abv
# 0          United States  ...       NaN
# 1                Alabama  ...        AL
# 2                 Alaska  ...        AK
# 3                Arizona  ...        AZ
# 4               Arkansas  ...        AR
# 5             California  ...        CA
# 6               Colorado  ...        CO
# 7            Connecticut  ...        CT
# 8               Delaware  ...        DE
# 9   District of Columbia  ...        DC
# 10               Florida  ...        FL
# 11               Georgia  ...        GA
# 12                Hawaii  ...        HI
# 13                 Idaho  ...        ID
# 14              Illinois  ...        IL
# 15               Indiana  ...        IN
# 16                  Iowa  ...        IA
# 17                Kansas  ...        KS
# 18              Kentucky  ...        KY
# 19             Louisiana  ...        LA
# 20                 Maine  ...        ME
# 21              Maryland  ...        MD
# ...

# %%
# running a small descripitive analysis 
# we see all Dtype are object and will need modification
# there are 52 entires, when there are 50 states
# these are USA and District of Columbia as the 2 additionals

df_election.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 15 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   State                                52 non-null     object
#  1   Source                               40 non-null     object
#  2   Official/Unofficial                  25 non-null     object
#  3   Total Ballots Counted (Estimate)     52 non-null     object
#  4   Vote for Highest Office (President)  24 non-null     object
#  5   VEP Turnout Rate                     52 non-null     object
#  6   Voting-Eligible Population (VEP)     52 non-null     object
#  7   Voting-Age Population (VAP)          52 non-null     object
#  8   % Non-citizen                        52 non-null     object
#  9   Prison                               52 non-null     object
#  10  Probation                            52 non-null     object
# ...

# %%
# testing iloc on index 10 to see the stats for Florida
df_election.iloc[10]
# Out:
# State                                                                            Florida
# Source                                 https://floridaelectionwatch.gov/CountyReporti...
# Official/Unofficial                                                                  NaN
# Total Ballots Counted (Estimate)                                              11,150,000
# Vote for Highest Office (President)                                                  NaN
# VEP Turnout Rate                                                                   71.7%
# Voting-Eligible Population (VEP)                                              15,551,739
# Voting-Age Population (VAP)                                                   17,543,341
# % Non-citizen                                                                      10.1%
# Prison                                                                            91,674
# ...

# %%
# We want to see the VEP and VAP of each state so we pull those out 
# of the dataset
df_graph = df_election[['State',
                       'Voting-Eligible Population (VEP)',
                       'Voting-Age Population (VAP)',]]

# %%
# pulling out the x axis to clean later
xaxis_1 = df_graph['State']

# %%
# pulling out the y axis to clean later
yaxis_1 = df_graph['Voting-Eligible Population (VEP)']
yaxis_2 = df_graph['Voting-Age Population (VAP)']

# %%
# verifying the data types
df_graph.dtypes
# Out:
# State                               object
# Voting-Eligible Population (VEP)    object
# Voting-Age Population (VAP)         object
# dtype: object

# %%
# removing the commas in our y axis columns
# because we will want to turn the column into numeric later
yaxis_1_num = yaxis_1.replace(',', '', regex = True)
yaxis_2_num = yaxis_2.replace(',','', regex = True)

# %%
# verification that commas are removed
yaxis_1_num
# Out:
# 0     239247182
# 1       3683055
# 2        525568
# 3       5189000
# 4       2182375
# 5      25962648
# 6       4313054
# 7       2603327
# 8        720531
# 9        540685
# 10     15551739
# 11      7383562
# 12      1007920
# 13      1292701
# 14      9027082
# 15      5000007
# 16      2321131
# 17      2087946
# 18      3312250
# 19      3373932
# 20      1085285
# 21      4313416
# 22      5072901
# 23      7550147
# 24      4118462
# 25      2201950
# 26      4603060
# 27       837298
# 28      1383551
# 29      2153915
# 30      1079434
# 31      6158999
# 32      1515355
# 33     13670596
# 34      7759051
# 35       565143
# 36      8859167
# 37      2845835
# 38      3196425
# 39      9781976
# 40       799642
# 41      3926305
# 42       648104
# 43      5124867
# 44     18784280
# 45      2191487
# 46       499884
# 47      6196071
# 48      5437844
# 49      1394028
# 50      4368530
# 51       431364
# Name: Voting-Eligible Population (VEP), dtype: object

# %%
# Dropping old versions of VEP and VAP and saving to new variable
df_graph_prep = df_graph.drop(['Voting-Eligible Population (VEP)',
               'Voting-Age Population (VAP)' ] ,axis = 1)

# %%
df_graph_prep.insert
# Out:
# <bound method DataFrame.insert of                    State
# 0          United States
# 1                Alabama
# 2                 Alaska
# 3                Arizona
# 4               Arkansas
# 5             California
# 6               Colorado
# 7            Connecticut
# 8               Delaware
# 9   District of Columbia
# 10               Florida
# 11               Georgia
# 12                Hawaii
# 13                 Idaho
# 14              Illinois
# 15               Indiana
# 16                  Iowa
# 17                Kansas
# 18              Kentucky
# 19             Louisiana
# 20                 Maine
# 21              Maryland
# 22         Massachusetts
# 23              Michigan
# 24             Minnesota
# 25           Mississippi
# 26              Missouri
# 27               Montana
# 28              Nebraska
# 29                Nevada
# 30         New Hampshire
# 31            New Jersey
# 32            New Mexico
# 33              New York
# ...

# %%
df_graph_prep
# Out:
#                    State
# 0          United States
# 1                Alabama
# 2                 Alaska
# 3                Arizona
# 4               Arkansas
# 5             California
# 6               Colorado
# 7            Connecticut
# 8               Delaware
# 9   District of Columbia
# 10               Florida
# 11               Georgia
# 12                Hawaii
# 13                 Idaho
# 14              Illinois
# 15               Indiana
# 16                  Iowa
# 17                Kansas
# 18              Kentucky
# 19             Louisiana
# 20                 Maine
# 21              Maryland
# 22         Massachusetts
# 23              Michigan
# 24             Minnesota
# 25           Mississippi
# 26              Missouri
# 27               Montana
# 28              Nebraska
# 29                Nevada
# 30         New Hampshire
# 31            New Jersey
# 32            New Mexico
# 33              New York
# 34        North Carolina
# 35          North Dakota
# ...

# %%
yaxis_1_num
# Out:
# 0     239247182
# 1       3683055
# 2        525568
# 3       5189000
# 4       2182375
# 5      25962648
# 6       4313054
# 7       2603327
# 8        720531
# 9        540685
# 10     15551739
# 11      7383562
# 12      1007920
# 13      1292701
# 14      9027082
# 15      5000007
# 16      2321131
# 17      2087946
# 18      3312250
# 19      3373932
# 20      1085285
# 21      4313416
# 22      5072901
# 23      7550147
# 24      4118462
# 25      2201950
# 26      4603060
# 27       837298
# 28      1383551
# 29      2153915
# 30      1079434
# 31      6158999
# 32      1515355
# 33     13670596
# 34      7759051
# 35       565143
# 36      8859167
# 37      2845835
# 38      3196425
# 39      9781976
# 40       799642
# 41      3926305
# 42       648104
# 43      5124867
# 44     18784280
# 45      2191487
# 46       499884
# 47      6196071
# 48      5437844
# 49      1394028
# 50      4368530
# 51       431364
# Name: Voting-Eligible Population (VEP), dtype: object

# %%
# entering comma removed values into df_graph_prep
# as VEP and VAP
df_graph_prep['VEP'] = yaxis_1_num
df_graph_prep['VAP'] = yaxis_2_num

# %%
# previewing the data
# the type is still not correcet for VEP and VAP
df_graph_prep
# Out:
#                    State        VEP        VAP
# 0          United States  239247182  257605088
# 1                Alabama    3683055    3837540
# 2                 Alaska     525568     551117
# 3                Arizona    5189000    5798473
# 4               Arkansas    2182375    2331171
# 5             California   25962648   30783255
# 6               Colorado    4313054    4595504
# 7            Connecticut    2603327    2839560
# 8               Delaware     720531     780822
# 9   District of Columbia     540685     582065
# 10               Florida   15551739   17543341
# 11               Georgia    7383562    8255108
# 12                Hawaii    1007920    1114466
# 13                 Idaho    1292701    1384683
# 14              Illinois    9027082    9832749
# 15               Indiana    5000007    5214546
# 16                  Iowa    2321131    2439743
# 17                Kansas    2087946    2223238
# 18              Kentucky    3312250    3479257
# ...

# %%
# convert object into int
df_insert_VEP = df_graph_prep['VEP'].astype(str).astype(int)

# %%
# convert object into int
df_insert_VAP = df_graph_prep['VAP'].astype(str).astype(int)

# %%
# making a new column of VEP but now as usable int data
df_graph_prep['VEP1'] = df_insert_VEP

# %%
# making a new column of VAP but now as usable int data
df_graph_prep['VAP1'] = df_insert_VAP

# %%
df_graph_prep
# Out:
#                    State        VEP        VAP       VEP1       VAP1
# 0          United States  239247182  257605088  239247182  257605088
# 1                Alabama    3683055    3837540    3683055    3837540
# 2                 Alaska     525568     551117     525568     551117
# 3                Arizona    5189000    5798473    5189000    5798473
# 4               Arkansas    2182375    2331171    2182375    2331171
# 5             California   25962648   30783255   25962648   30783255
# 6               Colorado    4313054    4595504    4313054    4595504
# 7            Connecticut    2603327    2839560    2603327    2839560
# 8               Delaware     720531     780822     720531     780822
# 9   District of Columbia     540685     582065     540685     582065
# 10               Florida   15551739   17543341   15551739   17543341
# 11               Georgia    7383562    8255108    7383562    8255108
# 12                Hawaii    1007920    1114466    1007920    1114466
# ...

# %%
# removing previous unusable columns 
df_graph_prep_2 = df_graph_prep.drop(labels = ['State','VEP','VAP'], axis = 1)

# %%
df_graph_prep_2.head()
# Out:
#         VEP1       VAP1
# 0  239247182  257605088
# 1    3683055    3837540
# 2     525568     551117
# 3    5189000    5798473
# 4    2182375    2331171

# %%
# removing what was the united states with indexing
df_graph_prep_3 = df_graph_prep_2.drop([0])

# %%
df_graph_prep_3.head()
# Out:
#        VEP1      VAP1
# 1   3683055   3837540
# 2    525568    551117
# 3   5189000   5798473
# 4   2182375   2331171
# 5  25962648  30783255

# %%
# setting State to abv format of two letters like NY, FL
 
df_state = df_election['State Abv']
df_state = df_state.dropna()
df_graph_prep_3['State'] = df_state

# %%
# creating a seperate var for sorted values of VEP for the first bar chart

df_graph_vep_sort = df_graph_prep_3.sort_values(by = 'VEP1',ascending= False)

# %%
# creating a seperate var for sorted values of VAP for the second bar chart
df_graph_vap_sort = df_graph_prep_3.sort_values(by = 'VAP1',ascending= False)

# %%
# preview to see the data is sorted
df_graph_vap_sort.head()
# Out:
#         VEP1      VAP1 State
# 5   25962648  30783255    CA
# 44  18784280  22058260    TX
# 10  15551739  17543341    FL
# 33  13670596  15372655    NY
# 39   9781976  10186170    PA

# %% [markdown]
# ## Insight 1
# # We see here that the top 5 states with voter eligible population
# # California, Texas, Florida, New York, Pennsylvania
#
# California has double the voter eligible population that Pennsylvania has. Showing us that if all the VEP in CA were to vote, it could nullify what the VEP of PA voted for if there was a neck and neck race with opposing canidates.

# %%
plt.figure(figsize = (22,12))
plt.barh(df_graph_vep_sort['State'], df_graph_vep_sort['VEP1'], color ='red')

# plot which shows State on the y-axis and VEP on the x-axis in millions.
# for example: 2.5 means 25 Million
# Out:
# <BarContainer object of 51 artists>

# %% [markdown]
# ## Insight 2
# # In terms of Voting-Age Population
# # we see the same top states as the previous insight.
# # the top states have more population of age that can vote
# # this holds a lot of voting power
# # California has 55 votes in the electoral college for a winning canidate in the state

# %%
# creating/plotting a figure with the figure size being preset to be 22 by 12 pixels
# using seaborn lib, create a barplot with out x-axis labeled 'State'
# y-axis labeled 'Voting-Age Population'
# the data being reflected on graph being df_graph_vap_sort

plt.figure(figsize = (22,12))
sns.barplot(x = 'State', y = 'VAP1', data=df_graph_vap_sort)

# %% [markdown]
# ## Insight 3
# # In this graph we have overlayed Voting-Age population
# # with Voter-Eligible population
# # this gives us a clear distinction of who is eligible to vote within that group
# # We see that California is our biggest state in terms of VAP, but there are a lot of people who are not eligible to vote.
# # This could be prisoners who have lost their right to vote or those above the age of 18 who haven't registered. But there is also a disparity in terms of the data, because we only see prisoners who are removed from the Voting-Eligible population, but there are others who were removed from this pool for other reasons that the dataset does not explain.

# %%
fig, ax = plt.subplots(figsize=(30,12))

ax = sns.barplot(x = 'State', y = 'VAP1', data=df_graph_vap_sort, color ='grey')
ax = sns.barplot(x = 'State', y = 'VEP1', data=df_graph_vep_sort, color = 'red')

plt.legend(labels = ["VAP", "VEP"], title = 'VAP vs VEP')
plt.show()

# the unfilled gray portions of the graph
# indicate that you are either a prisoner who lost their voting rights
# or did not register to vote
#VAP = Voting Age Population: includes any citizen over the age of 18
#VEP = Voting Eligible Population: includes any citizen over the age of 18 that is not a felon and is registered to vote

# %%
df_graph_prep_3
# Out:
#         VEP1      VAP1 State
# 1    3683055   3837540    AL
# 2     525568    551117    AK
# 3    5189000   5798473    AZ
# 4    2182375   2331171    AR
# 5   25962648  30783255    CA
# 6    4313054   4595504    CO
# 7    2603327   2839560    CT
# 8     720531    780822    DE
# 9     540685    582065    DC
# 10  15551739  17543341    FL
# 11   7383562   8255108    GA
# 12   1007920   1114466    HI
# 13   1292701   1384683    ID
# 14   9027082   9832749    IL
# 15   5000007   5214546    IN
# 16   2321131   2439743    IA
# 17   2087946   2223238    KS
# 18   3312250   3479257    KY
# 19   3373932   3557594    LA
# 20   1085285   1104489    ME
# 21   4313416   4729400    MD
# 22   5072901   5566452    MA
# 23   7550147   7870864    MI
# 24   4118462   4378737    MN
# 25   2201950   2279412    MS
# 26   4603060   4794796    MO
# 27    837298    851663    MT
# 28   1383551   1469878    NE
# 29   2153915   2450946    NV
# 30   1079434   1115916    NH
# 31   6158999   6952008    NJ
# ...

# %%
df_vap_vep_sub = df_graph_prep_3['VAP1'] - df_graph_prep_3['VEP1']
df_graph_prep_3['VAP-VEP'] = df_vap_vep_sub

# %%
df_graph_prep_3.sort_values(by = 'VAP-VEP', ascending= False, inplace = True)

# %% [markdown]
# ## Insight 4
# # We wanted to observe the raw difference between the voting age population and the voting eligible population
# # There is a vast amount of people who are old enough to vote but due to many circumstances could not. This data only shows a snippet of the complexity in voting laws between the states.

# %%
# using seaborn lib, create a barplot graph 
# data reflected on graph is data stored in df_graph_prep_3
# x-axis labeled with values in 'VAP-VEP'
# y-axis labeled with values in 'State'
# sets aesthetic paratemeters such as adjusting the size of our figure/graph

sns.barplot(x='VAP-VEP', y='State', data=df_graph_prep_3)
sns.set(rc={'figure.figsize':(25,15)})

# %% [markdown]
# # Part 3

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as go

# %%
# checking to see that df_election remains untouched and usable as source variable
# for dataset
df_election.head()
# Out:
#            State  ... State Abv
# 0  United States  ...       NaN
# 1        Alabama  ...        AL
# 2         Alaska  ...        AK
# 3        Arizona  ...        AZ
# 4       Arkansas  ...        AR
#
# [5 rows x 15 columns]

# %%
# verifying the data types in the lastest graph prep variable
df_graph_prep_3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 51 entries, 5 to 46
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   VEP1     51 non-null     int64
#  1   VAP1     51 non-null     int64
#  2   State    51 non-null     object
#  3   VAP-VEP  51 non-null     int64
# dtypes: int64(3), object(1)
# memory usage: 4.5+ KB

# %%
# creating a new variable that holds the 'Total Ballots Counted (Estimate)'
# this will then be cleaned by removing the ',' at a later time
df_ballot_count = df_election['Total Ballots Counted (Estimate)']
df_ballot_count.head()
# Out:
# 0    158,835,004
# 1      2,306,587
# 2        367,000
# 3      3,400,000
# 4      1,212,030
# Name: Total Ballots Counted (Estimate), dtype: object

# %%
# creating a new graph_prep variable to leave the previous unchanged as 
# this is new section for data analysis

df_graph_prep_4 = df_graph_prep_3

# %%
# adding a column to graph prep 4
# from the previously created variable that contained
# the ballot count columns
df_graph_prep_4['Total Ballot Count Estimate'] = df_ballot_count

# %%
# verifying that they merged properly
# note that the new column is still and object type
df_graph_prep_4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 51 entries, 5 to 46
# Data columns (total 5 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   VEP1                         51 non-null     int64
#  1   VAP1                         51 non-null     int64
#  2   State                        51 non-null     object
#  3   VAP-VEP                      51 non-null     int64
#  4   Total Ballot Count Estimate  51 non-null     object
# dtypes: int64(3), object(2)
# memory usage: 4.9+ KB

# %%
# remove commas from column in ballot count in previous variable 
df_ballot_count.replace(',', '', regex = True, inplace= True)

# %%
# saving the type change into a var called col_insert, so we can insert it into graph_prep 4

col_insert = df_ballot_count.astype({"Total Ballots Counted (Estimate)": int}, errors = 'raise')

# %%
# adding a new column to graph_prep_4 from col_insert
df_graph_prep_4['Total Ballot Count (Estimated)'] = col_insert

# %%
df_graph_prep_4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 51 entries, 5 to 46
# Data columns (total 6 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   VEP1                            51 non-null     int64
#  1   VAP1                            51 non-null     int64
#  2   State                           51 non-null     object
#  3   VAP-VEP                         51 non-null     int64
#  4   Total Ballot Count Estimate     51 non-null     object
#  5   Total Ballot Count (Estimated)  51 non-null     int64
# dtypes: int64(4), object(2)
# memory usage: 5.3+ KB

# %%
df_graph_prep_4.drop(labels = 'Total Ballot Count Estimate', axis = 1, inplace = True)

# %%
df_state_prep = df_election['State Abv']
df_state_prep.head()
# Out:
# 0    NaN
# 1     AL
# 2     AK
# 3     AZ
# 4     AR
# Name: State Abv, dtype: object

# %%
df_state_prep = df_state_prep.dropna()

# %%
# Final data 
df_graph_final = df_graph_prep_4

# %%
df_graph_final.drop(labels = 'State', axis = 1, inplace = True)

# %%
df_graph_final['State'] = df_state_prep

# %%
df_graph_final
# Out:
#         VEP1      VAP1  VAP-VEP  Total Ballot Count (Estimated) State
# 5   25962648  30783255  4820607                        16800000    CA
# 44  18784280  22058260  3273980                        11300000    TX
# 10  15551739  17543341  1991602                        11150000    FL
# 33  13670596  15372655  1702059                         8930000    NY
# 11   7383562   8255108   871546                         5025000    GA
# 14   9027082   9832749   805667                         6100000    IL
# 31   6158999   6952008   793009                         4495000    NJ
# 48   5437844   6070046   632202                         4100000    WA
# 3    5189000   5798473   609473                         3400000    AZ
# 34   7759051   8328642   569591                         5600000    NC
# 47   6196071   6727440   531369                         4425000    VA
# 22   5072901   5566452   493551                         3725000    MA
# ...

# %%
# sorting values so the chart is more readable from left to right
df_graph_final = df_graph_final.sort_values(by = 'VEP1',ascending= False)

# %%
# creating a subplot, and assigning the figure size
fig, ax = plt.subplots(figsize=(30,12))

# creating stacked bar charts
# the VEP1 bar chart will be marked in grey to show the total voting eligible people
# the red bar is the second bar chart to overlap the grey bar to show the
# disparty between the ballots cast
ax = sns.barplot(x = 'State', y = 'VEP1', data=df_graph_final, color ='grey')
ax = sns.barplot(x = 'State', y = 'Total Ballot Count (Estimated)', data=df_graph_final, color = 'red')

# testing to see if a legend would appear
# more testing is needed to allocate its color
# and size
plt.legend(labels = ["VEP", "Total Ballot Count (Estimated)"], title = 'VEP vs Total Ballot Count (Estimated)')
plt.show()

# %% [markdown]
# ## Insight 5
#
# In this graph we are looking at voting-eligible population and
# total ballots cast.
# We see an interesting trend of the top 5 states once again appearing.
#
# California, Texas, Florida, New York, Pennsylvania
#
# There is a huge difference in ballots cast (estimated) to the amount of people who can actually vote in California. 9.6 Million people estimated, who were eligible did not vote.
# In a previous insight, we saw that California had the most VEP meaning they could swing elections with their 55 electoral votes.
#
# Political canidates have 9.6 Million missing votes they can potentially win to swing the state in their favor. Those 55 electoral votes can be pivotal in a campaign win. Texas holds very similar possiblities with the amount of VEP that do not cast votes.

# %%
# setting the width variable with anchos to 0.5

anchos = 0.5

# passing the .Figure function from plotly 

fig = go.Figure()

# assigning the x-axis and y-axis for 'Voting Eligible Population'
# this will be the graph in the 'back' showing the total eligible population
# in blue
fig.add_trace(go.Bar( x = df_graph_final['State'],
                      y = df_graph_final['VEP1'],
                     width = anchos, name = 'Voting Eligible Population'
                     ))

# assigning the x-axis and the y-axis for 'Total Ballot Count (Estimated)'
# this will be the graph in the 'front' showing the estimated ballot count
# an offset is introduced here, to make it more apparent
fig.add_trace(go.Bar(x = df_graph_final['State'],
                     y = df_graph_final['Total Ballot Count (Estimated)'],
                     offset = 0.0005,
                     width = anchos,
                     name = 'Ballot Count Estimated'
                     ))

# the title is named here, and the size of the chart is set to 1280x1024
# font size is set to 30
fig.update_layout(title = "Voting Eligible Population to Ballots Cast (Estimated) per State",
               barmode = "overlay",
               title_font_size = 30,
               width = 1280,
               height = 1024)
# X axis is updated to State
fig.update_xaxes(
                title_text = 'State'
)
# Y axis is updated to 'Voter Eligible Population to Ballots Cast'
fig.update_yaxes(
                title_text = 'Voter Eligible Population to Ballots Cast'
)
# How does the eligible population compare to the ballot count of each state?
# Thus, we can see which state had the greatest turnout rate as well.
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="d3ae85b6-1fba-4aa4-878f-b87e12a6694c" class="plotly-graph-div" style="height:1024px; width:1280px;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("d3ae85b6-1fba-4aa4-878f-b87e12a6694c")) {
#                     Plotly.newPlot(
#                         'd3ae85b6-1fba-4aa4-878f-b87e12a6694c',
# ...

# %% [markdown]
# Side project:
#
# Get the population density for California,
# See the ratio of ballots cast to voter eligible population by population density
#
# Then see if this can be repeated for other states.
#
# Population Density =
#  ( Number of People / Land Area )
#
#  Population Density =
#  ( VEP / CA land area )
#
#   Population Density =
#   ( 25,962,648 / 155,779.2 square miles )
#
#
# [ Land Area = 155,779.2 square miles
#
#  239.1 persons per square mile in    California ]
#
# source for land area:
#  (https://www.census.gov/geographies/reference-files/2010/geo/state-local-geo-guides-2010/california.html)
